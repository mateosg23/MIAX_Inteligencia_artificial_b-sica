# %% [markdown]
# # Structure Learning in Bayesian Networks

# %%
# !pip install pgmpy
# Out:
# Collecting pgmpy
#   Downloading pgmpy-1.1.0-py3-none-any.whl.metadata (13 kB)
# Collecting huggingface_hub>=0.23 (from pgmpy)
#   Downloading huggingface_hub-1.11.0-py3-none-any.whl.metadata (14 kB)
# Collecting networkx>=3.0 (from pgmpy)
#   Downloading networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: numpy>=2.0 in c:\users\mateo\anaconda31\envs\trading\lib\site-packages (from pgmpy) (2.4.2)
# Requirement already satisfied: scipy>=1.10 in c:\users\mateo\anaconda31\envs\trading\lib\site-packages (from pgmpy) (1.17.0)
# Requirement already satisfied: scikit-learn>=1.2 in c:\users\mateo\anaconda31\envs\trading\lib\site-packages (from pgmpy) (1.8.0)
# Requirement already satisfied: pandas>=1.5 in c:\users\mateo\anaconda31\envs\trading\lib\site-packages (from pgmpy) (2.3.3)
# Requirement already satisfied: statsmodels>=0.14.5 in c:\users\mateo\anaconda31\envs\trading\lib\site-packages (from pgmpy) (0.14.6)
# Requirement already satisfied: tqdm>=4.64 in c:\users\mateo\anaconda31\envs\trading\lib\site-packages (from pgmpy) (4.67.3)
# Requirement already satisfied: pyparsing>=3.0 in c:\users\mateo\anaconda31\envs\trading\lib\site-packages (from pgmpy) (3.2.5)
# Requirement already satisfied: joblib>=1.2 in c:\users\mateo\anaconda31\envs\trading\lib\site-packages (from pgmpy) (1.5.3)
# Collecting opt_einsum>=3.3 (from pgmpy)
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting scikit-base>=0.12.4 (from pgmpy)
#   Downloading scikit_base-0.13.2-py3-none-any.whl.metadata (8.8 kB)
# Collecting filelock>=3.10.0 (from huggingface_hub>=0.23->pgmpy)
#   Downloading filelock-3.28.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting fsspec>=2023.5.0 (from huggingface_hub>=0.23->pgmpy)
#   Downloading fsspec-2026.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting hf-xet<2.0.0,>=1.4.3 (from huggingface_hub>=0.23->pgmpy)
#   Downloading hf_xet-1.4.3-cp37-abi3-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\mateo\anaconda31\envs\trading\lib\site-packages (from huggingface_hub>=0.23->pgmpy) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\mateo\anaconda31\envs\trading\lib\site-packages (from huggingface_hub>=0.23->pgmpy) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\mateo\anaconda31\envs\trading\lib\site-packages (from huggingface_hub>=0.23->pgmpy) (6.0.3)
# Collecting typer (from huggingface_hub>=0.23->pgmpy)
#   Downloading typer-0.24.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\mateo\anaconda31\envs\trading\lib\site-packages (from huggingface_hub>=0.23->pgmpy) (4.15.0)
# Requirement already satisfied: anyio in c:\users\mateo\anaconda31\envs\trading\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.23->pgmpy) (3.7.1)
# Requirement already satisfied: certifi in c:\users\mateo\anaconda31\envs\trading\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.23->pgmpy) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\mateo\anaconda31\envs\trading\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.23->pgmpy) (1.0.9)
# Requirement already satisfied: idna in c:\users\mateo\anaconda31\envs\trading\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.23->pgmpy) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\mateo\anaconda31\envs\trading\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub>=0.23->pgmpy) (0.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mateo\anaconda31\envs\trading\lib\site-packages (from pandas>=1.5->pgmpy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mateo\anaconda31\envs\trading\lib\site-packages (from pandas>=1.5->pgmpy) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\mateo\anaconda31\envs\trading\lib\site-packages (from pandas>=1.5->pgmpy) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\mateo\anaconda31\envs\trading\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.5->pgmpy) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\mateo\anaconda31\envs\trading\lib\site-packages (from scikit-learn>=1.2->pgmpy) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\mateo\anaconda31\envs\trading\lib\site-packages (from statsmodels>=0.14.5->pgmpy) (1.0.2)
# Requirement already satisfied: colorama in c:\users\mateo\anaconda31\envs\trading\lib\site-packages (from tqdm>=4.64->pgmpy) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\mateo\anaconda31\envs\trading\lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface_hub>=0.23->pgmpy) (1.3.1)
# Collecting click>=8.2.1 (from typer->huggingface_hub>=0.23->pgmpy)
#   Downloading click-8.3.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting shellingham>=1.3.0 (from typer->huggingface_hub>=0.23->pgmpy)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=12.3.0 (from typer->huggingface_hub>=0.23->pgmpy)
#   Downloading rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting annotated-doc>=0.0.2 (from typer->huggingface_hub>=0.23->pgmpy)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=12.3.0->typer->huggingface_hub>=0.23->pgmpy)
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\mateo\anaconda31\envs\trading\lib\site-packages (from rich>=12.3.0->typer->huggingface_hub>=0.23->pgmpy) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface_hub>=0.23->pgmpy)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading pgmpy-1.1.0-py3-none-any.whl (2.4 MB)
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.4 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.4 MB 3.0 MB/s eta 0:00:01
#    ------------------------------ --------- 1.8/2.4 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.1/2.4 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.4/2.4 MB 2.6 MB/s  0:00:00
# Downloading huggingface_hub-1.11.0-py3-none-any.whl (645 kB)
#    ---------------------------------------- 0.0/645.5 kB ? eta -:--:--
#    ---------------------------------------- 645.5/645.5 kB 4.1 MB/s  0:00:00
# Downloading hf_xet-1.4.3-cp37-abi3-win_amd64.whl (3.7 MB)
#    ---------------------------------------- 0.0/3.7 MB ? eta -:--:--
#    ----------- ---------------------------- 1.0/3.7 MB 5.6 MB/s eta 0:00:01
#    ------------------- -------------------- 1.8/3.7 MB 4.8 MB/s eta 0:00:01
#    ------------------------- -------------- 2.4/3.7 MB 3.8 MB/s eta 0:00:01
#    ------------------------------- -------- 2.9/3.7 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 3.7/3.7 MB 3.4 MB/s  0:00:01
# Downloading filelock-3.28.0-py3-none-any.whl (39 kB)
# Downloading fsspec-2026.3.0-py3-none-any.whl (202 kB)
# Downloading networkx-3.6.1-py3-none-any.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    -------------------- ------------------- 1.0/2.1 MB 4.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.8/2.1 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 3.9 MB/s  0:00:00
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading scikit_base-0.13.2-py3-none-any.whl (160 kB)
# Downloading typer-0.24.1-py3-none-any.whl (56 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading click-8.3.2-py3-none-any.whl (108 kB)
# Downloading rich-15.0.0-py3-none-any.whl (310 kB)
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Installing collected packages: shellingham, scikit-base, opt_einsum, networkx, mdurl, hf-xet, fsspec, filelock, click, annotated-doc, markdown-it-py, rich, typer, huggingface_hub, pgmpy
#
#    -- -------------------------------------  1/15 [scikit-base]
#    -- -------------------------------------  1/15 [scikit-base]
#    -- -------------------------------------  1/15 [scikit-base]
#    -- -------------------------------------  1/15 [scikit-base]
#    -- -------------------------------------  1/15 [scikit-base]
#    -- -------------------------------------  1/15 [scikit-base]
#    -- -------------------------------------  1/15 [scikit-base]
#    -- -------------------------------------  1/15 [scikit-base]
#    ----- ----------------------------------  2/15 [opt_einsum]
#    ----- ----------------------------------  2/15 [opt_einsum]
#    ----- ----------------------------------  2/15 [opt_einsum]
#    ----- ----------------------------------  2/15 [opt_einsum]
#    -------- -------------------------------  3/15 [networkx]
#    -------- -------------------------------  3/15 [networkx]
#    -------- -------------------------------  3/15 [networkx]
#    -------- -------------------------------  3/15 [networkx]
#    -------- -------------------------------  3/15 [networkx]
#    -------- -------------------------------  3/15 [networkx]
#    -------- -------------------------------  3/15 [networkx]
#    -------- -------------------------------  3/15 [networkx]
#    -------- -------------------------------  3/15 [networkx]
#    -------- -------------------------------  3/15 [networkx]
#    -------- -------------------------------  3/15 [networkx]
#    -------- -------------------------------  3/15 [networkx]
#    -------- -------------------------------  3/15 [networkx]
#    -------- -------------------------------  3/15 [networkx]
#    -------- -------------------------------  3/15 [networkx]
#    -------- -------------------------------  3/15 [networkx]
#    -------- -------------------------------  3/15 [networkx]
#    -------- -------------------------------  3/15 [networkx]
#    -------- -------------------------------  3/15 [networkx]
#    -------- -------------------------------  3/15 [networkx]
#    -------- -------------------------------  3/15 [networkx]
#    -------- -------------------------------  3/15 [networkx]
#    -------- -------------------------------  3/15 [networkx]
#    -------- -------------------------------  3/15 [networkx]
#    -------- -------------------------------  3/15 [networkx]
#    -------- -------------------------------  3/15 [networkx]
#    -------- -------------------------------  3/15 [networkx]
#    -------- -------------------------------  3/15 [networkx]
#    -------- -------------------------------  3/15 [networkx]
#    -------- -------------------------------  3/15 [networkx]
#    -------- -------------------------------  3/15 [networkx]
#    -------- -------------------------------  3/15 [networkx]
#    -------- -------------------------------  3/15 [networkx]
#    -------- -------------------------------  3/15 [networkx]
#    -------- -------------------------------  3/15 [networkx]
#    -------- -------------------------------  3/15 [networkx]
#    -------- -------------------------------  3/15 [networkx]
#    -------- -------------------------------  3/15 [networkx]
#    -------- -------------------------------  3/15 [networkx]
#    -------- -------------------------------  3/15 [networkx]
#    -------- -------------------------------  3/15 [networkx]
#    -------- -------------------------------  3/15 [networkx]
#    -------- -------------------------------  3/15 [networkx]
#    -------- -------------------------------  3/15 [networkx]
#    -------- -------------------------------  3/15 [networkx]
#    -------- -------------------------------  3/15 [networkx]
#    ------------- --------------------------  5/15 [hf-xet]
#    ---------------- -----------------------  6/15 [fsspec]
#    ---------------- -----------------------  6/15 [fsspec]
#    ---------------- -----------------------  6/15 [fsspec]
#    ---------------- -----------------------  6/15 [fsspec]
#    ---------------- -----------------------  6/15 [fsspec]
#    ------------------ ---------------------  7/15 [filelock]
#    --------------------- ------------------  8/15 [click]
#    --------------------- ------------------  8/15 [click]
#    --------------------- ------------------  8/15 [click]
#    -------------------------- ------------- 10/15 [markdown-it-py]
#    -------------------------- ------------- 10/15 [markdown-it-py]
#    -------------------------- ------------- 10/15 [markdown-it-py]
#    -------------------------- ------------- 10/15 [markdown-it-py]
#    -------------------------- ------------- 10/15 [markdown-it-py]
#    ----------------------------- ---------- 11/15 [rich]
#    ----------------------------- ---------- 11/15 [rich]
#    ----------------------------- ---------- 11/15 [rich]
#    ----------------------------- ---------- 11/15 [rich]
#    ----------------------------- ---------- 11/15 [rich]
#    ----------------------------- ---------- 11/15 [rich]
#    ----------------------------- ---------- 11/15 [rich]
#    ----------------------------- ---------- 11/15 [rich]
#    ----------------------------- ---------- 11/15 [rich]
#    ----------------------------- ---------- 11/15 [rich]
#    -------------------------------- ------- 12/15 [typer]
#    ---------------------------------- ----- 13/15 [huggingface_hub]
#    ---------------------------------- ----- 13/15 [huggingface_hub]
#    ---------------------------------- ----- 13/15 [huggingface_hub]
#    ---------------------------------- ----- 13/15 [huggingface_hub]
#    ---------------------------------- ----- 13/15 [huggingface_hub]
#    ---------------------------------- ----- 13/15 [huggingface_hub]
#    ---------------------------------- ----- 13/15 [huggingface_hub]
#    ---------------------------------- ----- 13/15 [huggingface_hub]
#    ---------------------------------- ----- 13/15 [huggingface_hub]
#    ---------------------------------- ----- 13/15 [huggingface_hub]
#    ---------------------------------- ----- 13/15 [huggingface_hub]
#    ---------------------------------- ----- 13/15 [huggingface_hub]
#    ---------------------------------- ----- 13/15 [huggingface_hub]
#    ---------------------------------- ----- 13/15 [huggingface_hub]
#    ------------------------------------- -- 14/15 [pgmpy]
#    ------------------------------------- -- 14/15 [pgmpy]
#    ------------------------------------- -- 14/15 [pgmpy]
#    ------------------------------------- -- 14/15 [pgmpy]
#    ------------------------------------- -- 14/15 [pgmpy]
#    ------------------------------------- -- 14/15 [pgmpy]
#    ------------------------------------- -- 14/15 [pgmpy]
#    ------------------------------------- -- 14/15 [pgmpy]
#    ------------------------------------- -- 14/15 [pgmpy]
#    ------------------------------------- -- 14/15 [pgmpy]
#    ------------------------------------- -- 14/15 [pgmpy]
#    ------------------------------------- -- 14/15 [pgmpy]
#    ------------------------------------- -- 14/15 [pgmpy]
#    ------------------------------------- -- 14/15 [pgmpy]
#    ------------------------------------- -- 14/15 [pgmpy]
#    ------------------------------------- -- 14/15 [pgmpy]
#    ------------------------------------- -- 14/15 [pgmpy]
#    ------------------------------------- -- 14/15 [pgmpy]
#    ------------------------------------- -- 14/15 [pgmpy]
#    ------------------------------------- -- 14/15 [pgmpy]
#    ------------------------------------- -- 14/15 [pgmpy]
#    ------------------------------------- -- 14/15 [pgmpy]
#    ------------------------------------- -- 14/15 [pgmpy]
#    ------------------------------------- -- 14/15 [pgmpy]
#    ------------------------------------- -- 14/15 [pgmpy]
#    ------------------------------------- -- 14/15 [pgmpy]
#    ------------------------------------- -- 14/15 [pgmpy]
#    ------------------------------------- -- 14/15 [pgmpy]
#    ------------------------------------- -- 14/15 [pgmpy]
#    ------------------------------------- -- 14/15 [pgmpy]
#    ------------------------------------- -- 14/15 [pgmpy]
#    ------------------------------------- -- 14/15 [pgmpy]
#    ------------------------------------- -- 14/15 [pgmpy]
#    ------------------------------------- -- 14/15 [pgmpy]
#    ------------------------------------- -- 14/15 [pgmpy]
#    ---------------------------------------- 15/15 [pgmpy]
#
# Successfully installed annotated-doc-0.0.4 click-8.3.2 filelock-3.28.0 fsspec-2026.3.0 hf-xet-1.4.3 huggingface_hub-1.11.0 markdown-it-py-4.0.0 mdurl-0.1.2 networkx-3.6.1 opt_einsum-3.4.0 pgmpy-1.1.0 rich-15.0.0 scikit-base-0.13.2 shellingham-1.5.4 typer-0.24.1

# %% [markdown]
# ## Load some data

# %%
from itertools import combinations

import networkx as nx
import pandas as pd
from sklearn.metrics import f1_score

from pgmpy.estimators import PC
#from pgmpy.utils import get_example_model
#from pgmpy.sampling import BayesianModelSampling
# Out:
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\__init__.py:4: FutureWarning: `pgmpy.estimators.StructureScore` is deprecated and will be removed in a future release. Use `pgmpy.structure_score` instead.
#   from .StructureScore import (

# %%
#data = pd.read_csv("bank_binary_short.csv")
data = pd.read_excel("bank_binary.xlsx")
samples = data

# %%
samples
# Out:
#        age           job   marital  education default housing loan    y
# 0       58    management   married   tertiary      no     yes   no   no
# 1       44    technician    single  secondary      no     yes   no   no
# 2       33  entrepreneur   married  secondary      no     yes  yes   no
# 3       47   blue-collar   married    unknown      no     yes   no   no
# 4       33       unknown    single    unknown      no      no   no   no
# ...    ...           ...       ...        ...     ...     ...  ...  ...
# 45206   51    technician   married   tertiary      no      no   no  yes
# 45207   71       retired  divorced    primary      no      no   no  yes
# 45208   72       retired   married  secondary      no      no   no  yes
# 45209   57   blue-collar   married  secondary      no      no   no   no
# 45210   37  entrepreneur   married  secondary      no      no   no   no
#
# [45211 rows x 8 columns]

# %% [markdown]
# ## Learn the model structure using PC

# %%
est = PC(data=samples)
estimated_model = est.estimate(variant="stable", max_cond_vars=4)
# Out:
# C:\Users\mateo\AppData\Local\Temp\ipykernel_5784\102194780.py:1: FutureWarning: PC is deprecated. Please use pgmpy.causal_discovery.PC instead.
#   est = PC(data=samples)
#   0%|          | 0/4 [00:00<?, ?it/s]
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# ...
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219: FutureWarning: `pillai_trace` is deprecated. Please use `pgmpy.ci_tests.PillaiTrace` instead.
#   if ci_test(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 est = PC(data=samples)
# ----> 2 estimated_model = est.estimate(variant="stable", max_cond_vars=4)
#
# File c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\PC.py:246, in PC.estimate(self, variant, ci_test, return_type, significance_level, max_cond_vars, expert_knowledge, enforce_expert_knowledge, n_jobs, show_progress, **kwargs)
#     243     expert_knowledge.limit_search_space(self.data.columns)
#     245 # Step 1: Run the PC algorithm to build the skeleton and get the separating sets.
# --> 246 skel, separating_sets = self.build_skeleton(
#     247     variant=variant,
#     248     ci_test=ci_test,
#     249     significance_level=significance_level,
#     250     max_cond_vars=max_cond_vars,
#     251     expert_knowledge=expert_knowledge,
#     252     enforce_expert_knowledge=enforce_expert_knowledge,
#     253     n_jobs=n_jobs,
#     254     show_progress=show_progress,
#     255     **kwargs,
#     256 )
#     258 if return_type.lower() == "skeleton":
#     259     return skel, separating_sets
#
# File c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\BaseConstraintEstimator.py:219, in BaseConstraintEstimator.build_skeleton(self, variant, ci_test, significance_level, max_cond_vars, expert_knowledge, enforce_expert_knowledge, n_jobs, show_progress, **kwargs)
#     213 if (enforce_expert_knowledge is False) or ((u, v) not in expert_knowledge.required_edges):
#     214     for separating_set in self._get_potential_sepsets(
#     215         u, v, temporal_ordering, graph, lim_neighbors
#     216     ):
#     217         # If a conditioning set exists remove the edge, store the
#     218         # separating set and move on to finding conditioning set for next edge.
# --> 219         if ci_test(
#     220             u,
#     221             v,
#     222             separating_set,
#     223             data=self.data,
#     224             independencies=self.independencies,
#     225             significance_level=significance_level,
#     226             **kwargs,
#     227         ):
#     228             separating_sets[frozenset((u, v))] = separating_set
#     229             graph.remove_edge(u, v)
#
# File c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\CITests.py:741, in pillai_trace(X, Y, Z, data, boolean, **kwargs)
#     738     data = data.assign(cont_Z=np.ones(data.shape[0]))
#     740 # Step 2: Get the predictions
# --> 741 pred_x, pred_y, x_cat_index, y_cat_index = _get_predictions(X, Y, Z, data, **kwargs)
#     743 # Step 3: Compute the residuals
#     744 def get_residuals(col_name, pred, cat_index):
#
# File c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\CITests.py:671, in _get_predictions(X, Y, Z, data, **kwargs)
#     667         pred = model.predict(data.loc[:, Z])
#     669     return pred, cat_index
# --> 671 pred_x, x_cat_index = fit_predict(X)
#     672 pred_y, y_cat_index = fit_predict(Y)
#     674 return pred_x, pred_y, x_cat_index, y_cat_index
#
# File c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\pgmpy\estimators\CITests.py:663, in _get_predictions.<locals>.fit_predict(target_col)
#     661 if is_cat:
#     662     y_encoded, cat_index = pd.factorize(target_data)
# --> 663     model.fit(data.loc[:, Z], y_encoded)
#     664     pred = model.predict_proba(data.loc[:, Z])
#     665 else:
#
# File c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\xgboost\core.py:751, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     749 for k, arg in zip(sig.parameters, args):
#     750     kwargs[k] = arg
# --> 751 return func(**kwargs)
#
# File c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\xgboost\sklearn.py:1806, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1786 evals_result: EvalsLog = {}
#    1787 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1788     missing=self.missing,
#    1789     X=X,
#    (...)   1803     feature_types=feature_types,
#    1804 )
# -> 1806 self._Booster = train(
#    1807     params,
#    1808     train_dmatrix,
#    1809     self.get_num_boosting_rounds(),
#    1810     evals=evals,
#    1811     early_stopping_rounds=self.early_stopping_rounds,
#    1812     evals_result=evals_result,
#    1813     obj=obj,
#    1814     custom_metric=metric,
#    1815     verbose_eval=verbose,
#    1816     xgb_model=model,
#    1817     callbacks=self.callbacks,
#    1818 )
#    1820 if not callable(self.objective):
#    1821     self.objective = params["objective"]
#
# File c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\xgboost\core.py:751, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     749 for k, arg in zip(sig.parameters, args):
#     750     kwargs[k] = arg
# --> 751 return func(**kwargs)
#
# File c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\xgboost\training.py:200, in train(params, dtrain, num_boost_round, evals, obj, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     198 if cb_container.before_iteration(bst, i, dtrain, evals):
#     199     break
# --> 200 bst.update(dtrain, iteration=i, fobj=obj)
#     201 if cb_container.after_iteration(bst, i, dtrain, evals):
#     202     break
#
# File c:\Users\mateo\anaconda31\envs\trading\Lib\site-packages\xgboost\core.py:2391, in Booster.update(self, dtrain, iteration, fobj)
#    2387 self._assign_dmatrix_features(dtrain)
#    2389 if fobj is None:
#    2390     _check_call(
# -> 2391         _LIB.XGBoosterUpdateOneIter(
#    2392             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2393         )
#    2394     )
#    2395     return
#    2397 # Forward the gradient calculation to the boost method.
#
# KeyboardInterrupt:

# %%
# Sin flechas
nodes = estimated_model.nodes()
est_adj = nx.to_numpy_array(
        estimated_model.to_undirected(), nodelist=nodes, weight=None
    )

# %%
import matplotlib.pyplot as plt

plt.imshow(est_adj)

# %%
# Con flechas
nodes = estimated_model.nodes()
est_adj = nx.to_numpy_array(
        estimated_model.to_directed(), nodelist=nodes, weight=None
    )

# %%
import matplotlib.pyplot as plt

plt.imshow(est_adj)

# %%
# !apt install libgraphviz-dev
# !pip install pygraphviz
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libgail-common libgail18 libgtk2.0-0 libgtk2.0-bin libgtk2.0-common libgvc6-plugins-gtk
#   librsvg2-common libxdot4
# Suggested packages:
#   gvfs
# The following NEW packages will be installed:
#   libgail-common libgail18 libgraphviz-dev libgtk2.0-0 libgtk2.0-bin libgtk2.0-common
#   libgvc6-plugins-gtk librsvg2-common libxdot4
# 0 upgraded, 9 newly installed, 0 to remove and 45 not upgraded.
# Need to get 2,434 kB of archives.
# After this operation, 7,694 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk2.0-common all 2.24.33-2ubuntu2.1 [125 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk2.0-0 amd64 2.24.33-2ubuntu2.1 [2,038 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgail18 amd64 2.24.33-2ubuntu2.1 [15.9 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgail-common amd64 2.24.33-2ubuntu2.1 [132 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libxdot4 amd64 2.42.2-6 [16.4 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgvc6-plugins-gtk amd64 2.42.2-6 [22.6 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgraphviz-dev amd64 2.42.2-6 [58.5 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk2.0-bin amd64 2.24.33-2ubuntu2.1 [7,936 B]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 librsvg2-common amd64 2.52.5+dfsg-3ubuntu0.2 [17.7 kB]
# Fetched 2,434 kB in 1s (3,349 kB/s)
# Selecting previously unselected package libgtk2.0-common.
# (Reading database ... 123586 files and directories currently installed.)
# Preparing to unpack .../0-libgtk2.0-common_2.24.33-2ubuntu2.1_all.deb ...
# Unpacking libgtk2.0-common (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgtk2.0-0:amd64.
# Preparing to unpack .../1-libgtk2.0-0_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgtk2.0-0:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgail18:amd64.
# Preparing to unpack .../2-libgail18_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgail18:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgail-common:amd64.
# Preparing to unpack .../3-libgail-common_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgail-common:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libxdot4:amd64.
# Preparing to unpack .../4-libxdot4_2.42.2-6_amd64.deb ...
# Unpacking libxdot4:amd64 (2.42.2-6) ...
# Selecting previously unselected package libgvc6-plugins-gtk.
# Preparing to unpack .../5-libgvc6-plugins-gtk_2.42.2-6_amd64.deb ...
# Unpacking libgvc6-plugins-gtk (2.42.2-6) ...
# Selecting previously unselected package libgraphviz-dev:amd64.
# Preparing to unpack .../6-libgraphviz-dev_2.42.2-6_amd64.deb ...
# Unpacking libgraphviz-dev:amd64 (2.42.2-6) ...
# Selecting previously unselected package libgtk2.0-bin.
# Preparing to unpack .../7-libgtk2.0-bin_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgtk2.0-bin (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package librsvg2-common:amd64.
# Preparing to unpack .../8-librsvg2-common_2.52.5+dfsg-3ubuntu0.2_amd64.deb ...
# Unpacking librsvg2-common:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Setting up libxdot4:amd64 (2.42.2-6) ...
# Setting up librsvg2-common:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Setting up libgtk2.0-common (2.24.33-2ubuntu2.1) ...
# Setting up libgtk2.0-0:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libgvc6-plugins-gtk (2.42.2-6) ...
# Setting up libgail18:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libgtk2.0-bin (2.24.33-2ubuntu2.1) ...
# Setting up libgail-common:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libgraphviz-dev:amd64 (2.42.2-6) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libgdk-pixbuf-2.0-0:amd64 (2.42.8+dfsg-1ubuntu0.3) ...
# Collecting pygraphviz
#   Downloading pygraphviz-1.13.tar.gz (104 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.6/104.6 kB 3.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: pygraphviz
#   Building wheel for pygraphviz (pyproject.toml) ... done
#   Created wheel for pygraphviz: filename=pygraphviz-1.13-cp310-cp310-linux_x86_64.whl size=168496 sha256=c8f16c9cd60f71f1bc3ec351d4d10368615b558b6c4028ab222ee513355f7f30
#   Stored in directory: /root/.cache/pip/wheels/c5/96/10/6c25add1fffc368b1927252bf73b63fcb938de8f4486e23691
# Successfully built pygraphviz
# Installing collected packages: pygraphviz
# Successfully installed pygraphviz-1.13

# %%
from IPython.display import Image
import pygraphviz

# Visualize the network
viz = estimated_model.to_graphviz()
viz.draw('estimated_model.png', prog='neato')
Image('estimated_model.png')
